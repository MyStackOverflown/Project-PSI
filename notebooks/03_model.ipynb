# %% [markdown]
# # Budowa i kompilacja modelu

# %% [markdown]
# Notebook spełnia fukcję budowy modelu. Obejmuje przygotowanie danych wejściowych, inicjalizację modelu oraz jego kompilację.

# %% [markdown]
# ## Setup środowiska

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/drive/MyDrive/Project-PSI/src/utils/setup

# %% [markdown]
# ## Przygotowanie komponentów

# %% [markdown]
# ### Importy

# %%
from src.models.model import build_model
from src.models.train import compile_model
from src.data.dataset import load_vocab_artifacts
from src.utils.paths import PROCESSED_DATA_DIR

# %% [markdown]
# ### Wczytanie słownika znaków

# %%
vocab, char2idx, idx2char = load_vocab_artifacts(PROCESSED_DATA_DIR)

# %% [markdown]
# ### Budowa modelu

# %%
model = build_model(
    vocab_size=len(vocab),
    embedding_dim=512,
    rnn_units=2048,
    batch_size=64
)

# %% [markdown]
# ### Kompilacja modelu

# %%
compile_model(model)
# Out:
# <Functional name=functional, built=True>

# %% [markdown]
# ### Podsumowanie modelu

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (64, None)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (64, None, 512)        │        46,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (64, None, 2048)       │    20,979,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (64, None, 90)         │       184,410 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,210,202 (80.91 MB)
#  Trainable params: 21,210,202 (80.91 MB)
# ...
