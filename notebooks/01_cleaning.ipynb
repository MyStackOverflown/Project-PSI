# %% [markdown]
# # Czyszczenie danych

# %% [markdown]
# Notebook odpowiedzialny za przygotowanie i czyszczenie danych tekstowych poprzez połączenie ich w jeden zbiór danych.

# %% [markdown]
# ## Setup środowiska

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/drive/MyDrive/Project-PSI/src/utils/setup

# %% [markdown]
# ## Przetwarzanie danych

# %% [markdown]
# ### Importy

# %%
from src.data.cleaning import combine_books
from src.utils.paths import RAW_DATA_DIR, PROCESSED_DATA_DIR

# %% [markdown]
# ### Konfiguracja plików wejściowych

# %%
raw_filenames = [
    "001ssb.txt",
    "002ssb.txt",
    "003ssb.txt",
    "004ssb.txt",
    "005ssb.txt"
]

# %% [markdown]
# ### Konfiguracja ścieżek wyjściowych

# %%
processed_path = PROCESSED_DATA_DIR / "asoiaf.txt"

# %% [markdown]
# ### Uruchomienie pipeline’u

# %%
combine_books(
    RAW_DATA_DIR,
    processed_path,
    raw_filenames
)
# Out:
# PosixPath('/content/drive/MyDrive/Project-PSI/data/processed/asoiaf.txt')

# %% [markdown]
# ### Weryfikacja wyniku

# %%
print(processed_path)
# Out:
# /content/drive/MyDrive/Project-PSI/data/processed/asoiaf.txt
