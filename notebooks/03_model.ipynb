# %% [markdown]
# # Model #

# %% [markdown]
# ## Importy ##

# %%
from src.models.model import build_model
from src.models.train import compile_model, get_checkpoint_callback

# %% [markdown]
# ## Budowa modelu ##

# %%
model = build_model(vocab_size=92, embedding_dim=256, rnn_units=1024, batch_size=64)
compile_model(model)
# Out:
# <Sequential name=sequential_5, built=True>

# %% [markdown]
# ## Test modelu ##

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (64, None, 256)        │        23,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (64, None, 1024)       │     5,246,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (64, None, 92)         │        94,300 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,364,828 (20.47 MB)
#  Trainable params: 5,364,828 (20.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Wrapper do checkpointów ##

# %%
checkpoint_callback = get_checkpoint_callback("models/checkpoints")
