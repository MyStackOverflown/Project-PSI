# %% [markdown]
# # Cleaning #

# %% [markdown]
# ## Importy ##

# %%
from pathlib import Path

from src.data.cleaning import combine_books

# %% [markdown]
# ## Podanie ścieżek ##

# %%
raw_dir = Path("../data/raw")
processed_path = Path("../data/processed/asoiaf.txt")

# %% [markdown]
# ## Podanie nazw plików ##

# %%
raw_filenames = ["001ssb.txt", "002ssb.txt", "003ssb.txt", "004ssb.txt", "005ssb.txt"]

# %% [markdown]
# ## Czyszczenie i łączenie ##

# %%
combine_books(raw_dir, processed_path, raw_filenames)
# Out:
# WindowsPath('../data/processed/asoiaf.txt')

# %% [markdown]
# ## Kontrola wyników ##

# %%
text = processed_path.read_text(encoding="utf-8")
print("Fragment tekstu: ", text[75:191])
print("Długość tekstu: ", len(text))
# Out:
# Fragment tekstu:
# PROLOGUE
# "We should start back," Gared urged as the woods began to grow dark around them. "The wildlings are
# dead."
# Długość tekstu:  9638137
